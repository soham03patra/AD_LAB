# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
gd = pd.read_csv("gradebook.csv")

# %%
gd

# %%
gd.shape

# %%
gd.info()

# %%
list(gd.columns)

# %%
gd.describe()

# %%
gd.Branch.describe()

# %%
gd.Branch.unique()

# %%
gd.head(n=2)

# %%
gd.tail(n=2)

# %%
#Coverting to Date
gd['ExamDate']=pd.to_datetime(gd['ExamDate'])

# %%
gd.info()

# %%
gd.ExamDate.describe()

# %%
gd['ExamDate'].dt.month

# %%
#Create Exam Month as a new column
gd['ExamMonth'] = gd['ExamDate'].dt.month
gd.head()

# %%
gd.Branch

# %%
gd['Branch']

# %%
#subsetting Columns
gd[['Marks_Course1', 'Marks_Course2', 'Marks_Course3']]

# %%
gd.Name # or gd[["Name"]]

# %%
#Returns a subsetted dataframe
gd[["Name","ExamDate"]]

# %%
# When Column indexes are not available

# %%
#Susetting as an array
gd.values[:,3:6]

# %%
gd.values[:5,3:6]

# %%
gd.iloc[5:,[2,5]]

# %%
#Subsetting as a dataframe
gd.iloc[0:2,[0,6]]

# %%
gd.iloc[0:5,1]

# %%
# filtering rows
#Names and ID of all students who have 
#scored less than 70 in course 1 and above 70 in  Course2
# Condition : (gd.Marks_Course1 <70) &(gd.Marks_Course2 >70)
#['Name','StudentID','Marks_Course1','Marks_Course2']

# %%
gd[(gd.Marks_Course1<70) & (gd.Marks_Course2>70)][['Name','StudentID','Marks_Course1','Marks_Course2']]

# %%
#Obtain the Names of the students who have taken the exam in MAR, APR

# %%
gd[(gd.ExamMonth==3) | (gd.ExamMonth==4)]['Name']

# %%
#NAmes of the students who have attended exam in months other than march
gd[~(gd.ExamMonth==3)]['Name']

# %%
# using query function
gd.query("(Marks_Course1 <70) &(Marks_Course2 >70)")\
[['Name','StudentID','Marks_Course1','Marks_Course2']]

# %%
# Names of students who have scored above 80 in course2 or course3

# %%
gd[(gd.Marks_Course2 > 80) | (gd.Marks_Course3 > 80)][['Name']]

# %%
#Student who has scored above 80 in second course 
# and scored below 80 in the third
gd.query("(Marks_Course2 >80) &(Marks_Course3 <80)")\
[['Name','StudentID','Marks_Course2','Marks_Course3']]

# %%
gd[gd.Name.isin(["Amit","Shankar","Vinay"])]

# %%
#Sort the data in the descending order on a particular column
gd.sort_values(by = 'Marks_Course1', ascending=False)

# %%
gd.sort_values(by = 'ExamDate', ascending=True)

# %%
# How do you sort the data on multiple columns
# 1. How do you sort the grade book monthwise in ascending order
# and Marks_course1 in descending order
gd.sort_values(by = ['ExamMonth','Marks_Course1'], 
               ascending=[True,False])

# %%
gd

# %%
gd.loc[5]

# %%
gd.loc[[1,7,8]]

# %%
gd[(gd.Name=='Priya') | (gd.Name == 'Shankar')]

# %%
list(gd.columns)

# %%
list(gd.index)

# %%
gd.set_index('Name',inplace=True)

# %%
list(gd.index)

# %%
gd.head()

# %%
gd.loc['Raghu']

# %%
gd.loc[['Priya','Raghu']]

# %%
gd.describe( )

# %%
#Describe using row indexes
gd.describe().loc[['mean','std']]

# %%
#Describe using row indexes
gd.describe().loc[['mean','std']]['Marks_Course1']

# %%
gd.reset_index(inplace=True)

# %%
gd
