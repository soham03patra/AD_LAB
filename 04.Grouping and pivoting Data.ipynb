# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("diamonds.csv")

# %%
data.shape

# %%
data.columns

# %%
data.info()

# %%
data.describe()

# %%
data.carat.describe()

# %%
data.head()

# %%
data.describe().loc['mean']['price']

# %%
data.describe().loc['count']['table']

# %%
data.groupby('color').size()

# %%
data.color.value_counts()

# %%
data.cut.value_counts()

# %%
data.groupby('cut').size()

# %%
data[['cut','price']].groupby('cut').sum()

# %%
data.groupby('cut').agg({'price':'sum','carat':'size'})

# %%
data.groupby('price').agg({'price':'sum','carat':'size'}).\
rename(columns={'price':'sum_of_price','carat':'count_of_recrods'})

# %%
data.groupby('color').agg({'price':['sum','mean'],'carat':'size'})

# %%
data.groupby(['color','cut']).agg({'price':'sum'}).\
rename(columns={'price':'sum_of_price'})

# %%
#Ouputs an aggregate in long format 
#Values Argument : column on which aggregate to be applied
# aggfunc Arg : which aggregate to be applied
# index : grouping column(s) to be displayed accros the rows
# columns : grouping column(s) to be displayed accross the columns
data.pivot_table(values = 'price',index = 'color',columns='cut',aggfunc='sum')

# %%
data.head()

# %%
df_cut_color = data.groupby(['color','cut']).agg({'price':'sum'}).\
rename(columns={'price':'sum_of_price'}).reset_index(inplace=False)
df_cut_color

# %%
df_cut_color_final = df_cut_color.pivot(index = "cut", columns = "color", values = "sum_of_price")

df_cut_color_final
